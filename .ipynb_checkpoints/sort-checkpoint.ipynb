# %% [markdown]
# # https://data.cityofnewyork.us/Health/New-York-City-Leading-Causes-of-Death/jb7j-dtam/about_data

# %%
import pandas as pd
import seaborn as sea
import matplotlib.pyplot as mat

raw_data = pd.read_csv("New_York_City_Leading_Causes_of_Death_20260713.csv")
raw_data
# Out:
#       Year                                      Leading Cause     Sex  \
# 0     2021  Mental and Behavioral Disorders due to Acciden...    Male
# 1     2021                                   All Other Causes  Female
# 2     2021               Chronic Liver Diseases and Cirrhosis    Male
# 3     2021     Diseases of Heart (I00-I09, I11, I13, I20-I51)  Female
# 4     2021            Influenza (Flu) and Pneumonia (J09-J18)    Male
# ...    ...                                                ...     ...
# 2097  2007                        Diabetes Mellitus (E10-E14)       F
# 2098  2007            Influenza (Flu) and Pneumonia (J09-J18)       F
# 2099  2007            Influenza (Flu) and Pneumonia (J09-J18)       F
# 2100  2007          Cerebrovascular Disease (Stroke: I60-I69)       M
# 2101  2007  Mental and Behavioral Disorders due to Use of ...       M
#
#              Race Ethnicity Deaths Death Rate Age Adjusted Death Rate
# 0     Other Race/ Ethnicity      9        NaN                     NaN
# 1        Not Stated/Unknown    102        NaN                     NaN
# 2        Not Stated/Unknown     16        NaN                     NaN
# 3                  Hispanic   1409        111                    95.5
# 4        Not Stated/Unknown     16        NaN                     NaN
# ...                     ...    ...        ...                     ...
# 2097     White Non-Hispanic    231       16.1                     9.8
# 2098     White Non-Hispanic    659       45.9                    23.2
# 2099     Not Stated/Unknown      .          .                       .
# 2100               Hispanic    126       11.6                      20
# 2101     Not Stated/Unknown      .          .                       .
#
# [2102 rows x 7 columns]

# %%
raw_data.dtypes
# Out:
# Year                        int64
# Leading Cause              object
# Sex                        object
# Race Ethnicity             object
# Deaths                     object
# Death Rate                 object
# Age Adjusted Death Rate    object
# dtype: object

# %%
raw_data["Leading Cause"].unique()
# Out:
# array(['Mental and Behavioral Disorders due to Accidental Poisoning and Other Psychoactive Substance Use (F11-F16, F18-F19, X40-X42, X44)',
#        'All Other Causes', 'Chronic Liver Diseases and Cirrhosis',
#        'Diseases of Heart (I00-I09, I11, I13, I20-I51)',
#        'Influenza (Flu) and Pneumonia (J09-J18)',
#        'Malignant Neoplasms (Cancer: C00-C97)', 'Covid-19',
#        'Cerebrovascular Disease (Stroke: I60-I69)',
#        "Alzheimer's Disease (G30)", 'Diabetes Mellitus (E10-E14)',
#        'Chronic Lower Respiratory Diseases (J40-J47)',
#        'Essential Hypertension and Renal Diseases (I10, I12, I15)',
#        'Mental and Behavioral Disorders due to Use of Alcohol (F10)',
#        'Intentional Self-Harm (Suicide: U03, X60-X84, Y87.0)',
#        'Accidents Except Drug Poisoning (V01-X39, X43, X45-X59, Y85-Y86)',
#        'Septicemia',
#        'Certain Conditions Originating in the Perinatal Period (P00-P96)',
#        'Chronic Liver Disease and Cirrhosis (K70, K73-K74)',
#        'Human Immunodeficiency Viruses Diseases',
#        'Assault (Homicide: U01-U02, Y87.1, X85-Y09)',
#        'Nephritis, Nephrotic Syndrome and Nephrisis (N00-N07, N17-N19, N25-N27)',
#        'Essential Hypertension and Renal Diseases (I10, I12)',
#        'Peptic Ulcer (K25-K28)', "Parkinson's Disease (G20)",
#        'Cholelithiasis and Disorders of Gallbladder (K80-K82)',
#        'Anemias (D50-D64)', 'Septicemia (A40-A41)',
#        'Congenital Malformations, Deformations, and Chromosomal Abnormalities (Q00-Q99)',
#        'Complications of Medical and Surgical Care (Y40-Y84, Y88)',
#        'Insitu or Benign / Uncertain Neoplasms (D00-D48)',
#        'Viral Hepatitis (B15-B19)',
#        'Aortic Aneurysm and Dissection (I71)',
#        'Certain Conditions originating in the Perinatal Period (P00-P96)',
#        'Human Immunodeficiency Virus Disease (HIV: B20-B24)',
#        'Pregnancy, Childbirth and the Puerperium (O00-O09)',
#        'Intentional Self-Harm (Suicide: X60-X84, Y87.0)',
#        'Chronic Liver Disease and Cirrhosis (K70, K73)',
#        'Atherosclerosis (I70)', 'Assault (Homicide: Y87.1, X85-Y09)',
#        'Meningitis (G00, G03)',
#        'Accidents Except Drug Posioning (V01-X39, X43, X45-X59, Y85-Y86)',
#        'Tuberculosis (A16-A19)'], dtype=object)

# %%
raw_data[raw_data["Leading Cause"] == "Influenza (Flu) and Pneumonia (J09-J18)"]
# Out:
#       Year                            Leading Cause     Sex  \
# 4     2021  Influenza (Flu) and Pneumonia (J09-J18)    Male
# 5     2021  Influenza (Flu) and Pneumonia (J09-J18)  Female
# 15    2021  Influenza (Flu) and Pneumonia (J09-J18)  Female
# 30    2021  Influenza (Flu) and Pneumonia (J09-J18)  Female
# 46    2021  Influenza (Flu) and Pneumonia (J09-J18)  Female
# ...    ...                                      ...     ...
# 2063  2007  Influenza (Flu) and Pneumonia (J09-J18)       M
# 2077  2007  Influenza (Flu) and Pneumonia (J09-J18)       M
# 2089  2007  Influenza (Flu) and Pneumonia (J09-J18)       F
# 2098  2007  Influenza (Flu) and Pneumonia (J09-J18)       F
# 2099  2007  Influenza (Flu) and Pneumonia (J09-J18)       F
#
#                   Race Ethnicity Deaths Death Rate Age Adjusted Death Rate
# 4             Not Stated/Unknown     16        NaN                     NaN
# 5          Other Race/ Ethnicity      4        NaN                     NaN
# 15                      Hispanic    169       13.3                    11.6
# 30    Asian and Pacific Islander     64        9.5                     7.5
# 46            Non-Hispanic White    293       21.4                    11.1
# ...                          ...    ...        ...                     ...
# 2063          Not Stated/Unknown     13          .                       .
# 2077          Black Non-Hispanic    229       26.9                    40.1
# 2089       Other Race/ Ethnicity      .          .                       .
# 2098          White Non-Hispanic    659       45.9                    23.2
# 2099          Not Stated/Unknown      .          .                       .
#
# [180 rows x 7 columns]

# %%
raw_data["Sex"] = raw_data["Sex"].replace("M","Male")
raw_data["Sex"] = raw_data["Sex"].replace("F","Female")
raw_data["Sex"].unique()
# Out:
# array(['Male', 'Female'], dtype=object)

# %%
fluData = raw_data[raw_data["Leading Cause"] == "Influenza (Flu) and Pneumonia (J09-J18)"]
fluData
# Out:
#       Year                            Leading Cause     Sex  \
# 4     2021  Influenza (Flu) and Pneumonia (J09-J18)    Male
# 5     2021  Influenza (Flu) and Pneumonia (J09-J18)  Female
# 15    2021  Influenza (Flu) and Pneumonia (J09-J18)  Female
# 30    2021  Influenza (Flu) and Pneumonia (J09-J18)  Female
# 46    2021  Influenza (Flu) and Pneumonia (J09-J18)  Female
# ...    ...                                      ...     ...
# 2063  2007  Influenza (Flu) and Pneumonia (J09-J18)    Male
# 2077  2007  Influenza (Flu) and Pneumonia (J09-J18)    Male
# 2089  2007  Influenza (Flu) and Pneumonia (J09-J18)  Female
# 2098  2007  Influenza (Flu) and Pneumonia (J09-J18)  Female
# 2099  2007  Influenza (Flu) and Pneumonia (J09-J18)  Female
#
#                   Race Ethnicity Deaths Death Rate Age Adjusted Death Rate
# 4             Not Stated/Unknown     16        NaN                     NaN
# 5          Other Race/ Ethnicity      4        NaN                     NaN
# 15                      Hispanic    169       13.3                    11.6
# 30    Asian and Pacific Islander     64        9.5                     7.5
# 46            Non-Hispanic White    293       21.4                    11.1
# ...                          ...    ...        ...                     ...
# 2063          Not Stated/Unknown     13          .                       .
# 2077          Black Non-Hispanic    229       26.9                    40.1
# 2089       Other Race/ Ethnicity      .          .                       .
# 2098          White Non-Hispanic    659       45.9                    23.2
# 2099          Not Stated/Unknown      .          .                       .
#
# [180 rows x 7 columns]

# %%
maleFluData = fluData[fluData["Sex"] != 'Female']
#columns = ["Leading Cause", "Sex","Race Ethnicity","Deaths","Death Rate","Age Adjusted Death Rate"]
#maleFluData2021 = maleFluData[fluData["Year"] == 2021]
maleFluData2021 = maleFluData2021[maleFluData2021["Race Ethnicity"] != "Not Stated/Unknown"]
maleFluData2021 = maleFluData2021[maleFluData2021["Race Ethnicity"] != "Other Race/ Ethnicity"]
maleFluData2021
# Out:
#      Year                            Leading Cause   Sex  \
# 85   2021  Influenza (Flu) and Pneumonia (J09-J18)  Male
# 94   2021  Influenza (Flu) and Pneumonia (J09-J18)  Male
# 108  2021  Influenza (Flu) and Pneumonia (J09-J18)  Male
# 124  2021  Influenza (Flu) and Pneumonia (J09-J18)  Male
#
#                  Race Ethnicity Deaths Death Rate Age Adjusted Death Rate
# 85                     Hispanic    195       16.3                    19.6
# 94   Asian and Pacific Islander    109       17.7                    16.4
# 108          Non-Hispanic White    339       25.7                    18.2
# 124          Non-Hispanic Black    196       23.2                    22.5

# %%
maleFluData2021 = maleFluData2021[maleFluData2021["Race Ethnicity"] != "Not Stated/Unknown"]
maleFluData2021 = maleFluData2021[maleFluData2021["Race Ethnicity"] != "Other Race/ Ethnicity"]
maleFluData2021
# Out:
#      Year                            Leading Cause   Sex  \
# 85   2021  Influenza (Flu) and Pneumonia (J09-J18)  Male
# 94   2021  Influenza (Flu) and Pneumonia (J09-J18)  Male
# 108  2021  Influenza (Flu) and Pneumonia (J09-J18)  Male
# 124  2021  Influenza (Flu) and Pneumonia (J09-J18)  Male
#
#                  Race Ethnicity Deaths Death Rate Age Adjusted Death Rate
# 85                     Hispanic    195       16.3                    19.6
# 94   Asian and Pacific Islander    109       17.7                    16.4
# 108          Non-Hispanic White    339       25.7                    18.2
# 124          Non-Hispanic Black    196       23.2                    22.5

# %%
years = [2017, 2018, 2019, 2020, 2021]

fig, axes = mat.subplots(1, 5, figsize=(20, 4))

for ax, year in zip(axes, years):
    yearData = maleFluData[maleFluData["Year"] == year]
    sea.barplot(data=yearData, x="Race Ethnicity", y="Death Rate", ax=ax)
    ax.set_title(str(year))
    ax.tick_params(axis='x', rotation=90)

mat.tight_layout()
mat.show()

# %%
determine = ["Leading Cause", "Sex",]
raw_data[["Year"] + determine].head()
# Out:
#    Year                                      Leading Cause     Sex
# 0  2021  Mental and Behavioral Disorders due to Acciden...    Male
# 1  2021                                   All Other Causes  Female
# 2  2021               Chronic Liver Diseases and Cirrhosis    Male
# 3  2021     Diseases of Heart (I00-I09, I11, I13, I20-I51)  Female
# 4  2021            Influenza (Flu) and Pneumonia (J09-J18)    Male

# %%
raw_data[determine].value_counts()
# Out:
# Leading Cause                                                     Deaths  Death Rate  Age Adjusted Death Rate
# Accidents Except Drug Posioning (V01-X39, X43, X45-X59, Y85-Y86)  .       .           .                          12
# Essential Hypertension and Renal Diseases (I10, I12)              .       .           .                          12
# Chronic Lower Respiratory Diseases (J40-J47)                      .       .           .                          10
# Cerebrovascular Disease (Stroke: I60-I69)                         .       .           .                          10
# Certain Conditions originating in the Perinatal Period (P00-P96)  .       .           .                          10
#                                                                                                                  ..
# Chronic Lower Respiratory Diseases (J40-J47)                      137     16.1        22.7                        1
#                                                                   132     11.9        22.8                        1
#                                                                           11.3        19.2                        1
#                                                                   123     10.7        19.2                        1
#                                                                   149     13          23.9                        1
# Name: count, Length: 1568, dtype: int64

# %%
counts = raw_data[determine].()
counts
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[25], line 1
# ----> 1 counts = raw_data[determine].sum()
#       2 counts
#
# File ~/.local/lib/python3.10/site-packages/pandas/core/frame.py:11697, in DataFrame.sum(self, axis, skipna, numeric_only, min_count, **kwargs)
#   11688 @doc(make_doc("sum", ndim=2))
#   11689 def sum(
#   11690     self,
#    (...)
#   11695     **kwargs,
#   11696 ):
# > 11697     result = super().sum(axis, skipna, numeric_only, min_count, **kwargs)
#   11698     return result.__finalize__(self, method="sum")
#
# File ~/.local/lib/python3.10/site-packages/pandas/core/generic.py:12571, in NDFrame.sum(self, axis, skipna, numeric_only, min_count, **kwargs)
#   12563 def sum(
#   12564     self,
#   12565     axis: Axis | None = 0,
#    (...)
#   12569     **kwargs,
#   12570 ):
# > 12571     return self._min_count_stat_function(
#   12572         "sum", nanops.nansum, axis, skipna, numeric_only, min_count, **kwargs
#   12573     )
#
# File ~/.local/lib/python3.10/site-packages/pandas/core/generic.py:12554, in NDFrame._min_count_stat_function(self, name, func, axis, skipna, numeric_only, min_count, **kwargs)
#   12551 elif axis is lib.no_default:
#   12552     axis = 0
# > 12554 return self._reduce(
#   12555     func,
#   12556     name=name,
#   12557     axis=axis,
#   12558     skipna=skipna,
#   12559     numeric_only=numeric_only,
#   12560     min_count=min_count,
#   12561 )
#
# File ~/.local/lib/python3.10/site-packages/pandas/core/frame.py:11589, in DataFrame._reduce(self, op, name, axis, skipna, numeric_only, filter_type, **kwds)
#   11585     df = df.T
#   11587 # After possibly _get_data and transposing, we are now in the
#   11588 #  simple case where we can use BlockManager.reduce
# > 11589 res = df._mgr.reduce(blk_func)
#   11590 out = df._constructor_from_mgr(res, axes=res.axes).iloc[0]
#   11591 if out_dtype is not None and out.dtype != "boolean":
#
# File ~/.local/lib/python3.10/site-packages/pandas/core/internals/managers.py:1519, in BlockManager.reduce(self, func)
#    1517 res_blocks: list[Block] = []
#    1518 for blk in self.blocks:
# -> 1519     nbs = blk.reduce(func)
#    1520     res_blocks.extend(nbs)
#    1522 index = Index([None])  # placeholder
#
# File ~/.local/lib/python3.10/site-packages/pandas/core/internals/blocks.py:406, in Block.reduce(self, func)
#     400 @final
#     401 def reduce(self, func) -> list[Block]:
#     402     # We will apply the function and reshape the result into a single-row
#     403     #  Block with the same mgr_locs; squeezing will be done at a higher level
#     404     assert self.ndim == 2
# --> 406     result = func(self.values)
#     408     if self.values.ndim == 1:
#     409         res_values = result
#
# File ~/.local/lib/python3.10/site-packages/pandas/core/frame.py:11508, in DataFrame._reduce.<locals>.blk_func(values, axis)
#   11506         return np.array([result])
#   11507 else:
# > 11508     return op(values, axis=axis, skipna=skipna, **kwds)
#
# File ~/.local/lib/python3.10/site-packages/pandas/core/nanops.py:85, in disallow.__call__.<locals>._f(*args, **kwargs)
#      81     raise TypeError(
#      82         f"reduction operation '{f_name}' not allowed for this dtype"
#      83     )
#      84 try:
# ---> 85     return f(*args, **kwargs)
#      86 except ValueError as e:
#      87     # we want to transform an object array
#      88     # ValueError message to the more typical TypeError
#      89     # e.g. this is normally a disallowed function on
#      90     # object arrays that contain strings
#      91     if is_object_dtype(args[0]):
#
# File ~/.local/lib/python3.10/site-packages/pandas/core/nanops.py:404, in _datetimelike_compat.<locals>.new_func(values, axis, skipna, mask, **kwargs)
#     401 if datetimelike and mask is None:
#     402     mask = isna(values)
# --> 404 result = func(values, axis=axis, skipna=skipna, mask=mask, **kwargs)
#     406 if datetimelike:
#     407     result = _wrap_results(result, orig_values.dtype, fill_value=iNaT)
#
# File ~/.local/lib/python3.10/site-packages/pandas/core/nanops.py:477, in maybe_operate_rowwise.<locals>.newfunc(values, axis, **kwargs)
#     474         results = [func(x, **kwargs) for x in arrs]
#     475     return np.array(results)
# --> 477 return func(values, axis=axis, **kwargs)
#
# File ~/.local/lib/python3.10/site-packages/pandas/core/nanops.py:646, in nansum(values, axis, skipna, min_count, mask)
#     643 elif dtype.kind == "m":
#     644     dtype_sum = np.dtype(np.float64)
# --> 646 the_sum = values.sum(axis, dtype=dtype_sum)
#     647 the_sum = _maybe_null_out(the_sum, axis, mask, values.shape, min_count=min_count)
#     649 return the_sum
#
# File ~/.local/lib/python3.10/site-packages/numpy/_core/_methods.py:52, in _sum(a, axis, dtype, out, keepdims, initial, where)
#      50 def _sum(a, axis=None, dtype=None, out=None, keepdims=False,
#      51          initial=_NoValue, where=True):
# ---> 52     return umr_sum(a, axis, dtype, out, keepdims, initial, where)
#
# TypeError: unsupported operand type(s) for +: 'int' and 'str'

# %%
long = raw_data.melt(
    id_vars=["Deaths"]["Death Rate"]["Year"],
    var_name="Death",
    value_var=Deaths,
    value_name=""
)

# %%
typecast_deaths = raw_data[['Deaths', 'Year']]
typecast_deaths['Deaths'].astype('string')
typecast_deaths.dtypes
# Out:
# Deaths    object
# Year       int64
# dtype: object

# %%
sea.lineplot(
    raw_data,
    y='Year',
    x='Death Rate',
)
# Out:
# <Axes: xlabel='Deaths', ylabel='Year'>

# %%
raw_data['Leading Cause'].value_counts()
# Out:
# Leading Cause
# All Other Causes                                                                                                                     182
# Diseases of Heart (I00-I09, I11, I13, I20-I51)                                                                                       182
# Malignant Neoplasms (Cancer: C00-C97)                                                                                                182
# Influenza (Flu) and Pneumonia (J09-J18)                                                                                              180
# Diabetes Mellitus (E10-E14)                                                                                                          176
# Cerebrovascular Disease (Stroke: I60-I69)                                                                                            174
# Chronic Lower Respiratory Diseases (J40-J47)                                                                                         166
# Essential Hypertension and Renal Diseases (I10, I12)                                                                                 134
# Mental and Behavioral Disorders due to Accidental Poisoning and Other Psychoactive Substance Use (F11-F16, F18-F19, X40-X42, X44)    101
# Alzheimer's Disease (G30)                                                                                                             82
# Accidents Except Drug Posioning (V01-X39, X43, X45-X59, Y85-Y86)                                                                      80
# Accidents Except Drug Poisoning (V01-X39, X43, X45-X59, Y85-Y86)                                                                      62
# Human Immunodeficiency Virus Disease (HIV: B20-B24)                                                                                   52
# Intentional Self-Harm (Suicide: X60-X84, Y87.0)                                                                                       41
# Certain Conditions originating in the Perinatal Period (P00-P96)                                                                      38
# Chronic Liver Disease and Cirrhosis (K70, K73)                                                                                        32
# Nephritis, Nephrotic Syndrome and Nephrisis (N00-N07, N17-N19, N25-N27)                                                               26
# Covid-19                                                                                                                              24
# Intentional Self-Harm (Suicide: U03, X60-X84, Y87.0)                                                                                  23
# Assault (Homicide: Y87.1, X85-Y09)                                                                                                    22
# Septicemia (A40-A41)                                                                                                                  21
# Essential Hypertension and Renal Diseases (I10, I12, I15)                                                                             19
# Chronic Liver Disease and Cirrhosis (K70, K73-K74)                                                                                    18
# Congenital Malformations, Deformations, and Chromosomal Abnormalities (Q00-Q99)                                                       15
# Mental and Behavioral Disorders due to Use of Alcohol (F10)                                                                           12
# Assault (Homicide: U01-U02, Y87.1, X85-Y09)                                                                                           11
# Viral Hepatitis (B15-B19)                                                                                                              8
# Insitu or Benign / Uncertain Neoplasms (D00-D48)                                                                                       6
# Aortic Aneurysm and Dissection (I71)                                                                                                   5
# Parkinson's Disease (G20)                                                                                                              4
# Atherosclerosis (I70)                                                                                                                  4
# Certain Conditions Originating in the Perinatal Period (P00-P96)                                                                       3
# Peptic Ulcer (K25-K28)                                                                                                                 3
# Chronic Liver Diseases and Cirrhosis                                                                                                   2
# Complications of Medical and Surgical Care (Y40-Y84, Y88)                                                                              2
# Anemias (D50-D64)                                                                                                                      2
# Cholelithiasis and Disorders of Gallbladder (K80-K82)                                                                                  2
# Septicemia                                                                                                                             2
# Human Immunodeficiency Viruses Diseases                                                                                                1
# Pregnancy, Childbirth and the Puerperium (O00-O09)                                                                                     1
# Meningitis (G00, G03)                                                                                                                  1
# Tuberculosis (A16-A19)                                                                                                                 1
# Name: count, dtype: int64

# %%
sort_year = raw_data[raw_data['Leading Cause'] =='Assault (Homicide: U01-U02, Y87.1, X85-Y09)']
sort_year_dec = sort_year.sort_values(by='Year')
sort_year_dec
# Out:
#      Year                                Leading Cause     Sex  \
# 832  2016  Assault (Homicide: U01-U02, Y87.1, X85-Y09)    Male
# 838  2016  Assault (Homicide: U01-U02, Y87.1, X85-Y09)  Female
# 791  2016  Assault (Homicide: U01-U02, Y87.1, X85-Y09)    Male
# 657  2017  Assault (Homicide: U01-U02, Y87.1, X85-Y09)    Male
# 550  2018  Assault (Homicide: U01-U02, Y87.1, X85-Y09)       M
# 542  2018  Assault (Homicide: U01-U02, Y87.1, X85-Y09)       M
# 318  2019  Assault (Homicide: U01-U02, Y87.1, X85-Y09)  Female
# 334  2019  Assault (Homicide: U01-U02, Y87.1, X85-Y09)    Male
# 419  2019  Assault (Homicide: U01-U02, Y87.1, X85-Y09)    Male
# 231  2020  Assault (Homicide: U01-U02, Y87.1, X85-Y09)    Male
# 121  2021  Assault (Homicide: U01-U02, Y87.1, X85-Y09)    Male
#
#             Race Ethnicity Deaths   Death Rate Age Adjusted Death Rate
# 832     Non-Hispanic Black    168  19.54013229             19.68635499
# 838  Other Race/ Ethnicity      1          NaN                     NaN
# 791  Other Race/ Ethnicity      1          NaN                     NaN
# 657     Non-Hispanic Black    133  15.44979224             15.64836771
# 550  Other Race/ Ethnicity      7          NaN                     NaN
# 542     Non-Hispanic Black    152       18.136                  18.171
# 318  Other Race/ Ethnicity      3          NaN                     NaN
# 334  Other Race/ Ethnicity      2          NaN                     NaN
# 419     Non-Hispanic Black    156  18.82411997             18.99230593
# 231     Non-Hispanic Black    281         32.3                    33.1
# 121     Non-Hispanic Black    291         34.4                    34.9

# %%
leading_cause_race = raw_data[raw_data['Race Ethnicity'] == 'Non-Hispanic Black']
assualts_on_black = leading_cause_race[leading_casue_race['Leading Cause'] =='Assault (Homicide: U01-U02, Y87.1, X85-Y09)']
assualts_on_black
#leading_cause_race = raw_data[raw_data['Race Ethnicity'] == 'Non-Hispanic Black']
# Out:
#      Year                                Leading Cause   Sex  \
# 121  2021  Assault (Homicide: U01-U02, Y87.1, X85-Y09)  Male
# 231  2020  Assault (Homicide: U01-U02, Y87.1, X85-Y09)  Male
# 419  2019  Assault (Homicide: U01-U02, Y87.1, X85-Y09)  Male
# 542  2018  Assault (Homicide: U01-U02, Y87.1, X85-Y09)     M
# 657  2017  Assault (Homicide: U01-U02, Y87.1, X85-Y09)  Male
# 832  2016  Assault (Homicide: U01-U02, Y87.1, X85-Y09)  Male
#
#          Race Ethnicity Deaths   Death Rate Age Adjusted Death Rate
# 121  Non-Hispanic Black    291         34.4                    34.9
# 231  Non-Hispanic Black    281         32.3                    33.1
# 419  Non-Hispanic Black    156  18.82411997             18.99230593
# 542  Non-Hispanic Black    152       18.136                  18.171
# 657  Non-Hispanic Black    133  15.44979224             15.64836771
# 832  Non-Hispanic Black    168  19.54013229             19.68635499

# %%
sea.lineplot(
    assualts_on_black,
    x='Year',
    y='Deaths',
)
# Out:
# <Axes: xlabel='Year', ylabel='Deaths'>

# %%
sea.kdeplot(
    assualts_on_black,
    x='Death Rate',
    fill = True,
)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[40], line 1
# ----> 1 sea.kdeplot(
#       2     assualts_on_black,
#       3     x='Death Rate',
#       4     fill = True,
#       5 )
#
# File ~/.local/lib/python3.10/site-packages/seaborn/distributions.py:1679, in kdeplot(data, x, y, hue, weights, palette, hue_order, hue_norm, color, fill, multiple, common_norm, common_grid, cumulative, bw_method, bw_adjust, warn_singular, log_scale, levels, thresh, gridsize, cut, clip, legend, cbar, cbar_ax, cbar_kws, ax, **kwargs)
#    1676 if ax is None:
#    1677     ax = plt.gca()
# -> 1679 p._attach(ax, allowed_types=["numeric", "datetime"], log_scale=log_scale)
#    1681 method = ax.fill_between if fill else ax.plot
#    1682 color = _default_color(method, hue, color, kwargs)
#
# File ~/.local/lib/python3.10/site-packages/seaborn/_base.py:1084, in VectorPlotter._attach(self, obj, allowed_types, log_scale)
#    1079     if var_type not in allowed_types:
#    1080         err = (
#    1081             f"The {var} variable is {var_type}, but one of "
#    1082             f"{allowed_types} is required"
#    1083         )
# -> 1084         raise TypeError(err)
#    1086 # -- Get axis objects for each row in plot_data for type conversions and scaling
#    1088 facet_dim = {"x": "col", "y": "row"}
#
# TypeError: The x variable is categorical, but one of ['numeric', 'datetime'] is required
